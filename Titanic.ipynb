# %% [markdown]
# <a href="https://colab.research.google.com/github/Raimundo2004/An-lise-de-dados-com-a-base-de-dados-do-Titanic/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Carregando a tabela do Titanic
titanic = pd.read_csv('/content/drive/MyDrive/Titanic/train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## **Tratando os dados**

# %%
#Analisando informações dos dados
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Notei que a coluna Age continha valores nulos. Para não perder informações importantes, optei por preenchê-los usando a média de idade calculada para cada grupo de passageiros, considerando o sexo e a classe do navio.

# %%
#Consultando a média por classes e sexo
titanic.groupby(["Pclass","Sex"])["Age"].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
#Preenchendo os dados nulos com base da minha consulta
titanic["Age"] = titanic["Age"].fillna(titanic.groupby(["Pclass","Sex"])["Age"].transform('mean'))

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male  27.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  21.75      1
# 889                              Behr, Mr. Karl Howell    male  26.00      0
# 890                                Dooley, Mr. Patrick    male  32.00      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Todas as colunas estão preenchisa, mas ainda tem algumas inconsistencias, onde os valores estão como float e então irei converter esses valores.

# %%
#Convertendo os dados floats para int
titanic["Age"] = titanic["Age"].astype(int)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Outra coluna que eu percebi que tem valores nulos e que posso usar eles, é a coluna 'Embarked'

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Procurando os valores nulos da coluna 'Embarked'
titanic[titanic["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572  80.0   B28      NaN
# 829  female   62      0      0  113572  80.0   B28      NaN

# %% [markdown]
# Pesquisei sobre essas duas passageiras e a embarcação delas eram de Southampton

# %%
#Tirando os valores nulos
titanic.loc[titanic.Embarked.isnull(),'Embarked']='S'

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# Decide criar mais uma coluna para de faixa etária, para facilitar a análise

# %%
def faixa_Etaria(idade):
  if idade < 18:
    return ("Child")
  elif idade < 55:
    return ("Adult")
  else:
    return ("Old")

# %%
#Testar a função para ver se estar funcionando
faixa_Etaria(6)
# Out:
# 'Child'

# %%
faixa_Etaria(20)
# Out:
# 'Adult'

# %%
faixa_Etaria(80)
# Out:
# 'Old'

# %%
#Com o código funcionando vou adicionar a coluna "Age_group"
titanic["Age_group"] = titanic["Age"].apply(faixa_Etaria)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   21      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked Age_group
# 0        0         A/5 21171   7.2500   NaN        S     Adult
# 1        0          PC 17599  71.2833   C85        C     Adult
# 2        0  STON/O2. 3101282   7.9250   NaN        S     Adult
# 3        0            113803  53.1000  C123        S     Adult
# 4        0            373450   8.0500   NaN        S     Adult
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     Adult
# 887      0            112053  30.0000   B42        S     Adult
# 888      2        W./C. 6607  23.4500   NaN        S     Adult
# 889      0            111369  30.0000  C148        C     Adult
# 890      0            370376   7.7500   NaN        Q     Adult
#
# [891 rows x 13 columns]

# %%
#Trocando os dados booleanos, 0 = não sobreviveu e 1= Sobreviveu, por inteiros para fica mais fácil a análise
def Survived(valor):
  if valor == 1:
    return "Survived"
  else:
    return "Not survived"

# %%
titanic["Survived"] = titanic["Survived"].apply(Survived)

# %%
titanic
# Out:
#      PassengerId      Survived  Pclass  \
# 0              1  Not survived       3
# 1              2      Survived       1
# 2              3      Survived       3
# 3              4      Survived       1
# 4              5  Not survived       3
# ..           ...           ...     ...
# 886          887  Not survived       2
# 887          888      Survived       1
# 888          889  Not survived       3
# 889          890      Survived       1
# 890          891  Not survived       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   21      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked Age_group
# 0        0         A/5 21171   7.2500   NaN        S     Adult
# 1        0          PC 17599  71.2833   C85        C     Adult
# 2        0  STON/O2. 3101282   7.9250   NaN        S     Adult
# 3        0            113803  53.1000  C123        S     Adult
# 4        0            373450   8.0500   NaN        S     Adult
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     Adult
# 887      0            112053  30.0000   B42        S     Adult
# 888      2        W./C. 6607  23.4500   NaN        S     Adult
# 889      0            111369  30.0000  C148        C     Adult
# 890      0            370376   7.7500   NaN        Q     Adult
#
# [891 rows x 13 columns]

# %%
#Criando mais uma função para outra coluna totalizando o número de parentes que embarcou junto com a pessoa
def parents_sum(titanic):
  total = titanic['SibSp'] + titanic['Parch']
  if total > 0:
    return(total)
  else:
    return(0)

# %%
titanic["Total_parents"] = titanic.apply(parents_sum,axis=1)
titanic
# Out:
#      PassengerId      Survived  Pclass  \
# 0              1  Not survived       3
# 1              2      Survived       1
# 2              3      Survived       3
# 3              4      Survived       1
# 4              5  Not survived       3
# ..           ...           ...     ...
# 886          887  Not survived       2
# 887          888      Survived       1
# 888          889  Not survived       3
# 889          890      Survived       1
# 890          891  Not survived       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 886                              Montvila, Rev. Juozas    male   27      0
# 887                       Graham, Miss. Margaret Edith  female   19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   21      1
# 889                              Behr, Mr. Karl Howell    male   26      0
# 890                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked Age_group  Total_parents
# 0        0         A/5 21171   7.2500   NaN        S     Adult              1
# 1        0          PC 17599  71.2833   C85        C     Adult              1
# 2        0  STON/O2. 3101282   7.9250   NaN        S     Adult              0
# 3        0            113803  53.1000  C123        S     Adult              1
# 4        0            373450   8.0500   NaN        S     Adult              0
# ..     ...               ...      ...   ...      ...       ...            ...
# 886      0            211536  13.0000   NaN        S     Adult              0
# 887      0            112053  30.0000   B42        S     Adult              0
# 888      2        W./C. 6607  23.4500   NaN        S     Adult              3
# 889      0            111369  30.0000  C148        C     Adult              0
# 890      0            370376   7.7500   NaN        Q     Adult              0
#
# [891 rows x 14 columns]

# %% [markdown]
# # **Analisando os dados**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Analisando o número de quantidade de passageiros por classes
sum_class=titanic.groupby(["Pclass"])["PassengerId"].size()
sum_class
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
#Criando um gráfico para facilitar a análise
plt.pie(sum_class, labels=sum_class.index, autopct='%1.1f%%')
plt.title("Distribuição de classes no Titanic")
plt.legend(title="Pclass")
plt.show()

# %%
#Quantidade de passageiros por embarcação
titanic.groupby(["Embarked"])["PassengerId"].size()
# Out:
# Embarked
# C    168
# Q     77
# S    646
# Name: PassengerId, dtype: int64

# %%
#Analisando se a classe influênciou no número de mortes no dia do acidente
counts_survide_Pclass = titanic.groupby(["Pclass","Survived"])["Name"].size().unstack()
counts_survide_Pclass
# Out:
# Survived  Not survived  Survived
# Pclass
# 1                   80       136
# 2                   97        87
# 3                  372       119

# %% [markdown]
# Essa consulta teve um resultado excelente, onde mostra que a classe influenciou nas mortes dos passageiros. Pois na [arquitetura do navio](https://www.encyclopedia-titanica.org/titanic-deckplans/), indicava quem era da primeira e segunda classe ficavam mais perto dos botes, já a terceira classe não.

# %%
#Gerando gráfico para melhorar a visualização
counts_survide_Pclass.plot(kind='bar')
plt.title("Quantidade de sobreviventes por classe")
# Out:
# Text(0.5, 1.0, 'Quantidade de sobreviventes por classe')

# %%
titanic.groupby(["Sex","Survived"])["Survived"].size().unstack()
# Out:
# Survived  Not survived  Survived
# Sex
# female              81       233
# male               468       109

# %%
titanic.groupby(["Age_group","Sex","Survived"])["Survived"].size().unstack()
# Out:
# Survived          Not survived  Survived
# Age_group Sex
# Adult     female            63       186
#           male             405        82
# Child     female            17        38
#           male              35        23
# Old       female             1         9
#           male              28         4

# %%
survived_sex = titanic.groupby(["Age_group","Survived"])["Survived"].size().unstack()
survived_sex
# Out:
# Survived   Not survived  Survived
# Age_group
# Adult               468       268
# Child                52        61
# Old                  29        13

# %%
survived_sex.plot(kind='bar')
plt.title("Faixa etária de sobreviventes no navio")
# Out:
# Text(0.5, 1.0, 'Faixa etária de sobreviventes no navio')

# %% [markdown]
# Com essas duas análises deu para perceber que crianças e mulheres sobreviveram mais que os homens, pois eles priorizaram mulheres e crianças primeiro no naufrágio.

# %%
titanic[(titanic["Parch"]>=2) & (titanic["Pclass"]==1)].head(10)
# Out:
#      PassengerId      Survived  Pclass                            Name  \
# 27            28  Not survived       1  Fortune, Mr. Charles Alexander
# 88            89      Survived       1      Fortune, Miss. Mabel Helen
# 136          137      Survived       1    Newsom, Miss. Helen Monypeny
# 297          298  Not survived       1    Allison, Miss. Helen Loraine
# 305          306      Survived       1  Allison, Master. Hudson Trevor
# 311          312      Survived       1      Ryerson, Miss. Emily Borie
# 318          319      Survived       1        Wick, Miss. Mary Natalie
# 341          342      Survived       1  Fortune, Miss. Alice Elizabeth
# 377          378  Not survived       1       Widener, Mr. Harry Elkins
# 390          391      Survived       1      Carter, Mr. William Ernest
#
#         Sex  Age  SibSp  Parch    Ticket      Fare            Cabin Embarked  \
# 27     male   19      3      2     19950  263.0000      C23 C25 C27        S
# 88   female   23      3      2     19950  263.0000      C23 C25 C27        S
# 136  female   19      0      2     11752   26.2833              D47        S
# 297  female    2      1      2    113781  151.5500          C22 C26        S
# 305    male    0      1      2    113781  151.5500          C22 C26        S
# 311  female   18      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 318  female   31      0      2     36928  164.8667               C7        S
# 341  female   24      3      2     19950  263.0000      C23 C25 C27        S
# 377    male   27      0      2    113503  211.5000              C82        C
# 390    male   36      1      2    113760  120.0000          B96 B98        S
#
#     Age_group  Total_parents
# 27      Adult              5
# 88      Adult              5
# 136     Adult              2
# 297     Child              3
# 305     Child              3
# 311     Adult              4
# 318     Adult              2
# 341     Adult              5
# 377     Adult              2
# 390     Adult              3

# %%
titanic.groupby(["Embarked"])["Fare"].mean()
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.243651
# Name: Fare, dtype: float64

# %%
titanic.groupby(["Pclass","Sex"])["Fare"].mean()
# Out:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
titanic[(titanic["SibSp"]>0)&(titanic["Parch"]>0)&(titanic["Pclass"]==3)]
# Out:
#      PassengerId      Survived  Pclass  \
# 7              8  Not survived       3
# 10            11      Survived       3
# 13            14  Not survived       3
# 16            17  Not survived       3
# 24            25  Not survived       3
# ..           ...           ...     ...
# 850          851  Not survived       3
# 852          853  Not survived       3
# 863          864  Not survived       3
# 869          870      Survived       3
# 888          889  Not survived       3
#
#                                          Name     Sex  Age  SibSp  Parch  \
# 7              Palsson, Master. Gosta Leonard    male    2      3      1
# 10            Sandstrom, Miss. Marguerite Rut  female    4      1      1
# 13                Andersson, Mr. Anders Johan    male   39      1      5
# 16                       Rice, Master. Eugene    male    2      4      1
# 24              Palsson, Miss. Torborg Danira  female    8      3      1
# ..                                        ...     ...  ...    ...    ...
# 850   Andersson, Master. Sigvard Harald Elias    male    4      4      2
# 852                   Boulos, Miss. Nourelain  female    9      1      1
# 863         Sage, Miss. Dorothy Edith "Dolly"  female   21      8      2
# 869           Johnson, Master. Harold Theodor    male    4      1      1
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   21      1      2
#
#          Ticket     Fare Cabin Embarked Age_group  Total_parents
# 7        349909  21.0750   NaN        S     Child              4
# 10      PP 9549  16.7000    G6        S     Child              2
# 13       347082  31.2750   NaN        S     Adult              6
# 16       382652  29.1250   NaN        Q     Child              5
# 24       349909  21.0750   NaN        S     Child              4
# ..          ...      ...   ...      ...       ...            ...
# 850      347082  31.2750   NaN        S     Child              6
# 852        2678  15.2458   NaN        C     Child              2
# 863    CA. 2343  69.5500   NaN        S     Adult             10
# 869      347742  11.1333   NaN        S     Child              2
# 888  W./C. 6607  23.4500   NaN        S     Adult              3
#
# [83 rows x 14 columns]

# %%
box = titanic.groupby(["Pclass","Total_parents"])["Fare"].mean().unstack()
box
# Out:
# Total_parents         0          1          2           3           4   \
# Pclass
# 1              63.672514  91.848039  95.681075  133.521429  262.375000
# 2              14.066106  24.682962  31.693819   36.575969   23.000000
# 3               9.272052  13.410023  16.378277   20.103689   26.972233
#
# Total_parents          5          6     7      10
# Pclass
# 1              263.000000        NaN   NaN    NaN
# 2               18.750000        NaN   NaN    NaN
# 3               32.420588  29.366667  46.9  69.55

# %% [markdown]
# Essa análise mostra que a tarifa não só aumenta com relação a classe, mas sim com a quantidade de parentes que foi junto com a pessoa a bordo, junto com a classe.

# %%
box.plot(kind='bar', figsize=(10, 6))
plt.title("Média de tarifa por classe e parentesco abordo")
plt.xlabel("Classes e parentes")
plt.ylabel("Média da tarifa")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Os protagonistas do filme Titanic, existiram mesmo ou eram ficticios?**

# %%
titanic[titanic["Name"].str.contains("Jack")]
# Out:
#      PassengerId      Survived  Pclass                       Name   Sex  Age  \
# 766          767  Not survived       1  Brewe, Dr. Arthur Jackson  male   41
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked Age_group  Total_parents
# 766      0      0  112379  39.6   NaN        C     Adult              0

# %%
titanic[titanic["Name"].str.contains("Rose")]
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex  Age  \
# 855          856  Survived       3  Aks, Mrs. Sam (Leah Rosen)  female   18
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked Age_group  Total_parents
# 855      0      1  392091  9.35   NaN        S     Adult              1

# %% [markdown]
# Com essa análise, percebe que [Jack Dawson](https://pt.wikipedia.org/wiki/Jack_Dawson), interpretado por Leonardo DiCaprio, e [Rose DeWitt Bukater](t.wikipedia.org/wiki/Rose_DeWitt_Bukater), interpretada por Kate Winslet, são fictícios, mas segundo o site [Aventuras na História](https://aventurasnahistoria.com.br/noticias/desventuras/titanic-o-que-aconteceu-com-mulher-da-vida-real-que-inspirou-rose.phtml), a Rose foi uma inspiração de Beatrice Wood, onde foi uma pessoa que naufrágiou no titanic.

# %%
# Group by Pclass and Embarked and calculate the mean fare
mean_fare_by_class_embarked = titanic.groupby(["Pclass", "Embarked"])["Fare"].mean().unstack()

# Plot the grouped data
mean_fare_by_class_embarked.plot(kind='bar', figsize=(10, 6))
plt.title("Mean Fare by Pclass and Embarked Location")
plt.xlabel("Pclass")
plt.ylabel("Mean Fare")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
